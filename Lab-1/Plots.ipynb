# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
V_1N914 = [0, 0.104, 0.206, 0.305, 0.394, 0.501, 0.602, 0.645, 0.709, 0.797, 0.852, 0.864, 0.873, 0.902, 1.000 ]
I_1N914 = [0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.4*1e-6, 1.3*1e-6, 8.9*1e-6, 37*1e-6, 57.3*1e-6, 94*1e-6, 153.3*1e-6, 192.1*1e-6, 1.261*1e-3, 1.305*1e-3, 1.427*1e-3, 1.893*1e-3]

# %%
plt.plot(V_1N914, I_1N914)
plt.title("I vs V Plot for 1N914")
plt.show()
plt.plot(V_1N914, np.log(I_1N914))
plt.title("log(I) vs V Plot for 1N914")
plt.show()

# %%
print(np.log(I_1N914))
# Out:
# [-15.42494847 -15.42494847 -15.42494847 -14.73180129 -13.55314629
#  -11.62945928 -10.20459265  -9.76720993  -9.27221578  -8.78311377
#   -8.55749449  -6.67585022  -6.64155224  -6.55218094  -6.26959241]

# %%
V_Zener = [-4.72, -4.49, -4.00, -3.55, -3.01, -2.52, -2.04, 0, 0.094, 0.197, 0.297, 0.398, 0.508, 0.595, 0.690, 0.801, 0.853, 0.909, 0.934, 0.950, 0.97, 1]
I_Zener = [-156.0*1e-6, -79.9*1e-6, -20.9*1e-6, -6.6*1e-6, -1.6*1e-6, -0.5*1e-6, -0.1*1e-6, 0.1*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.65*1e-6, 3*1e-6, 19.7*1e-6, 81.5*1e-6, 121.2*1e-6, 167.3*1e-6, 189*1e-6, 1.165*1e-3, 1.37*1e-3, 1.554*1e-3]

# %%
plt.plot(V_Zener, I_Zener)
plt.title("I vs V Plot for Zener")
plt.show()
plt.plot(V_Zener, np.log(np.absolute(I_Zener)))
plt.title("log(I) vs V Plot for Zener")
plt.show()

# %%
print(np.log(I_Zener))
# Out:
# [         nan          nan          nan          nan          nan
#           nan          nan -16.11809565 -15.42494847 -15.42494847
#  -15.42494847 -15.42494847 -14.24629347 -12.71689827 -10.83489192
#   -9.41490754  -9.01806848  -8.69572195  -8.57376354  -6.75503419
#   -6.59294454  -6.46692303]
# /tmp/ipykernel_846445/3296803755.py:1: RuntimeWarning: invalid value encountered in log
#   print(np.log(I_Zener))

# %%
V_Schottky = [0, 0.104, 0.210, 0.304, 0.402, 0.428, 0.45, 0.477, 0.504, 0.596, 0.709, 0.792]
I_Schottky = [0.2*1e-6, 1.1*1e-6, 22.7*1e-6, 81.3*1e-6, 160.7*1e-6, 181.6*1e-6, 1.31*1e-3, 1.45*1e-3, 1.59*1e-3, 4.38*1e-3, 5.55*1e-3, 6.49*1e-3]

# %%
plt.plot(V_Schottky, I_Schottky)
plt.title("I vs V Plot for Schottky")
plt.show()
plt.plot(V_Schottky, np.log(I_Schottky))
plt.title("log(I) vs V Plot for Schottky")
plt.show()

# %%
print(np.log(I_Schottky))
# Out:
# [-15.42494847 -13.72020038 -10.69314563  -9.41736454  -8.73597129
#   -8.61370409  -6.63772814  -6.53619172  -6.44402126  -5.43070655
#   -5.19395735  -5.03749275]

# %%
V_Green = [0, 0.107, 0.210, 0.315, 0.394, 0.513, 0.811, 1.002, 1.197, 2.11, 2.23, 2.32, 2.44, 2.52, 2.63, 2.75, 2.86, 2.97, 3.10, 3.15, 3.23, 3.39, 3.49]
I_Green = [0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.3*1e-6, 0.5*1e-6, 0.8*1e-6, 1.7*1e-6, 3.5*1e-6, 9.1*1e-6, 26.5*1e-6, 62.1*1e-6, 112.6*1e-6, 191.1*1e-6, 1.427*1e-3, 1.727*1e-3, 5.53*1e-3, 6.68*1e-3]

# %%
plt.plot(V_Green, I_Green)
plt.title("I vs V Plot for Green LED")
plt.show()
plt.plot(V_Green, np.log(I_Green))
plt.title("log(I) vs V Plot for Green LED")
plt.show()

# %%
print(np.log(I_Green))
# Out:
# [-15.42494847 -15.42494847 -15.42494847 -15.42494847 -15.42494847
#  -15.42494847 -15.42494847 -15.42494847 -15.42494847 -15.01948336
#  -14.50865774 -14.03865411 -13.28488231 -12.56274759 -11.60723614
#  -10.53836582  -9.68676457  -9.09166884  -8.56271371  -6.55218094
#   -6.36136948  -5.19756746  -5.00863729]

# %%
V_White = [0, 1.057, 1.600, 2.08, 2.38, 2.49, 2.58, 2.70, 2.80, 2.88, 2.90, 2.99, 3.12, 3.20, 3.28, 3.39, 3.48]
I_White = [0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 0.2*1e-6, 1.1*1e-6, 11.7*1e-6, 64.5*1e-6, 127.1*1e-6, 186*1e-6, 1.24*1e-3, 1.67*1e-3, 4.88*1e-3, 6.05*1e-3, 6.98*1e-3, 8.57*1e-3, 10.0*1e-3]

# %%
plt.plot(V_White, I_White)
plt.title("I vs V Plot for White LED")
plt.show()
plt.plot(V_White, np.log(I_White))
plt.title("log(I) vs V Plot for White LED")
plt.show()

# %%
print(np.log(I_White))
# Out:
# [-15.42494847 -15.42494847 -15.42494847 -15.42494847 -15.42494847
#  -13.72020038 -11.35592172  -9.64884533  -8.97053638  -8.58976388
#   -6.6926439   -6.39493165  -5.32261006  -5.10769701  -4.96470636
#   -4.75948755  -4.60517019]

# %%
V_Blue = [0, 2.12, 2.38, 2.49, 2.62, 2.71, 2.82, 2.91, 3.00, 3.08, 3.19, 3.27, 3.42, 3.49]
I_Blue = [0.2*1e-6, 0.2*1e-6, 0.3*1e-6, 1.9*1e-6, 27*1e-6, 71.9*1e-6, 136.6*1e-6, 1.22*1e-3, 1.6*1e-3, 1.93*1e-3, 5.14*1e-3, 6.16*1e-3, 7.96*1e-3, 8.71*1e-3]

# %%
plt.plot(V_Blue, I_Blue)
plt.title("I vs V Plot for Blue LED")
plt.show()
plt.plot(V_Blue, np.log(I_Blue))
plt.title("log(I) vs V Plot for Blue LED")
plt.show()

# %%
print(np.log(I_Blue))
# Out:
# [-15.42494847 -15.42494847 -15.01948336 -13.17365667 -10.51967369
#   -9.54023429  -8.89845361  -6.70890442  -6.43775165  -6.25023528
#   -5.2707022   -5.0896785   -4.83332628  -4.74328349]

# %%
V_Red = [0, 1.444, 1.616, 1.715, 1.806, 1.916, 2.04, 2.08, 2.18, 2.28, 2.39, 2.48]
I_Red = [0.2*1e-6, 0.2*1e-6, 1.6*1e-6, 11.9*1e-6, 49.0*1e-6, 121.7*1e-6, 175.8*1e-6, 1.314*1e-3, 1.825*1e-3, 5.01*1e-3, 6.37*1e-3, 7.61*1e-3]

# %%
plt.plot(V_Red, I_Red)
plt.title("I vs V Plot for Red LED")
plt.show()
plt.plot(V_Red, np.log(I_Red))
plt.title("log(I) vs V Plot for Red LED")
plt.show()

# %%
print(np.log(I_Red))
# Out:
# [-15.42494847 -15.42494847 -13.34550693 -11.33897216  -9.92369026
#   -9.01395156  -8.64616357  -6.63467936  -6.30617529  -5.29631936
#   -5.05615581  -4.87829211]

# %%
np.pi / 2
# Out:
# 1.5707963267948966

# %%
plt.scatter([1.97, 2.73, 2.76, 2.38], [2.05, 2.85, 2.89, 3.12])
plt.show()
