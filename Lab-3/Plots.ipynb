# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
V_PIN = [0.0001, 0.094, 0.208, 0.306, 0.398, 0.502, 0.604, 0.709, 0.805, 0.845, 0.905, 0.953, 1.009]
I_PIN = [0.0001, 76*1e-6, 77*1e-6, 116*1e-6, 128*1e-6, 167*1e-6, 208*1e-6, 278*1e-6, 378*1e-6, 447*1e-6, 683*1e-6, 890*1e-6, 4.83*1e-3]

# %%
plt.plot(V_PIN, I_PIN)
plt.title("I vs V Plot for PIN")
plt.show()
plt.plot(V_PIN, np.log(I_PIN))
plt.title("log(I) vs V Plot for PIN")
plt.show()
